# %%
import pandas as pd
# pd.set_option('display.max_rows', None)
import plotly.express as px
import seaborn as sns

# %%
df_common_player_info = pd.read_csv('common_player_info.csv')
df_common_player_info.head()
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76002       Zaid    Abdul-Aziz      Zaid Abdul-Aziz
# 2      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76006     Forest          Able          Forest Able
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1         Abdul-Aziz, Zaid    Z. Abdul-Aziz      zaid-abdul-aziz
# 2     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4             Able, Forest          F. Able          forest-able
#
#              birthdate            school country  ...  \
# 0  1968-06-24 00:00:00              Duke     USA  ...
# 1  1946-04-07 00:00:00        Iowa State     USA  ...
# ...

# %%
df_common_player_info.columns
# Out:
# Index(['person_id', 'first_name', 'last_name', 'display_first_last',
#        'display_last_comma_first', 'display_fi_last', 'player_slug',
#        'birthdate', 'school', 'country', 'last_affiliation', 'height',
#        'weight', 'season_exp', 'jersey', 'position', 'rosterstatus',
#        'games_played_current_season_flag', 'team_id', 'team_name',
#        'team_abbreviation', 'team_code', 'team_city', 'playercode',
#        'from_year', 'to_year', 'dleague_flag', 'nba_flag', 'games_played_flag',
#        'draft_year', 'draft_round', 'draft_number', 'greatest_75_flag'],
#       dtype='object')

# %%
df_common_player_info.drop(["display_first_last", "display_last_comma_first", "display_fi_last",
                             "player_slug", "birthdate", "games_played_current_season_flag",
                             "games_played_flag"], axis=1, inplace=True)
df_common_player_info
# Out:
#       person_id first_name     last_name            school  country  \
# 0         76001       Alaa     Abdelnaby              Duke      USA
# 1         76002       Zaid    Abdul-Aziz        Iowa State      USA
# 2         76003     Kareem  Abdul-Jabbar              UCLA      USA
# 3           949    Shareef   Abdur-Rahim        California      USA
# 4         76006     Forest          Able  Western Kentucky      USA
# ...         ...        ...           ...               ...      ...
# 3627    1627835       Paul        Zipser     Bayern Munich  Germany
# 3628    1627790       Ante         Zizic       Darussafaka  Croatia
# 3629      78647        Jim          Zoet        Kent State      USA
# 3630      78648       Bill          Zopf          Duquesne      USA
# 3631    1627826      Ivica         Zubac       Mega Basket  Croatia
#
#            last_affiliation height  weight  season_exp jersey  ...  \
# 0                  Duke/USA   6-10   240.0         5.0     30  ...
# ...

# %%
df_draft_history = pd.read_csv('draft_history.csv')
df_draft_history.head()
# Out:
#    person_id       player_name  season  round_number  round_pick  \
# 0      79299  Clifton McNeeley    1947             1           1
# 1      78109        Glen Selbo    1947             1           2
# 2      76649      Eddie Ehlers    1947             1           3
# 3      79302        Walt Dropo    1947             1           4
# 4      77048        Dick Holub    1947             1           5
#
#    overall_pick draft_type     team_id   team_city     team_name  \
# 0             1      Draft  1610610031  Pittsburgh       Ironmen
# 1             2      Draft  1610610035     Toronto       Huskies
# 2             3      Draft  1610612738      Boston       Celtics
# 3             4      Draft  1610610032  Providence  Steamrollers
# 4             5      Draft  1610612752    New York        Knicks
#
#   team_abbreviation          organization   organization_type  \
# 0               PIT         Texas-El Paso  College/University
# ...

# %%
df_draft_history.drop(["draft_type"], axis=1, inplace=True)

# %%
filter_df_draft_history = df_draft_history[df_draft_history["overall_pick"] <= 14]

# %%
df_draft_history_common_player_info = pd.merge(filter_df_draft_history, df_common_player_info, on= ("person_id", 'team_id'), how='outer',
                                               validate='one_to_one', suffixes=('_draft', '_player'))
df_draft_history_common_player_info
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_draft_history_common_player_info = pd.merge(filter_df_draft_history, df_common_player_info, on= ("person_id", 'team_id'), how='outer',
#       2                                                validate='one_to_one', suffixes=('_draft', '_player'))
#       3 df_draft_history_common_player_info
#
# File c:\Users\NewNoe\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:170, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     155     return _cross_merge(
#     156         left_df,
#     157         right_df,
#    (...)
#     167         copy=copy,
#     168     )
#     169 else:
# --> 170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#     173         how=how,
# ...

# %%
df_draft_history_common_player_info.columns
# Out:
# Index(['person_id', 'player_name', 'season', 'round_number', 'round_pick',
#        'overall_pick', 'team_id', 'team_city_draft', 'team_name_draft',
#        'team_abbreviation_draft', 'organization', 'organization_type',
#        'player_profile_flag', 'first_name', 'last_name', 'school', 'country',
#        'last_affiliation', 'height', 'weight', 'season_exp', 'jersey',
#        'position', 'rosterstatus', 'team_name_player',
#        'team_abbreviation_player', 'team_code', 'team_city_player',
#        'playercode', 'from_year', 'to_year', 'dleague_flag', 'nba_flag',
#        'draft_year', 'draft_round', 'draft_number', 'greatest_75_flag'],
#       dtype='object')

# %%
test = df_draft_history_common_player_info['team_id']
test
# Out:
# 0       1610612747
# 1                0
# 2       1610612743
# 3       1610612747
# 4       1610612746
#            ...
# 4241    1610612758
# 4242    1610612764
# 4243    1610612758
# 4244    1610612760
# 4245    1610612763
# Name: team_id, Length: 4246, dtype: int64

# %%
df_game = pd.read_csv('game.csv')
df_game.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id            game_date matchup_home wl_home  min  fgm_home  ...  \
# 0  24600001  1946-11-01 00:00:00  HUS vs. NYK       L    0      25.0  ...
# 1  24600003  1946-11-02 00:00:00  BOM vs. PIT       W    0      20.0  ...
# 2  24600002  1946-11-02 00:00:00  PRO vs. BOS       W    0      21.0  ...
# 3  24600004  1946-11-02 00:00:00  CHS vs. NYK       W    0      21.0  ...
# 4  24600005  1946-11-02 00:00:00  DEF vs. WAS       L    0      10.0  ...
#
# ...

# %%
df_game['game_date'] = pd.to_datetime(df_game['game_date'])
df_game['year'] = df_game['game_date'].dt.year.astype(int)
df_game= df_game[df_game['year'] >= 2010]
df_game = df_game[df_game['season_type'].isin(['Regular Season'])]

# %%
df_game.columns
# Out:
# Index(['season_id', 'team_id_home', 'team_abbreviation_home', 'team_name_home',
#        'game_id', 'game_date', 'matchup_home', 'wl_home', 'min', 'fgm_home',
#        'fga_home', 'fg_pct_home', 'fg3m_home', 'fg3a_home', 'fg3_pct_home',
#        'ftm_home', 'fta_home', 'ft_pct_home', 'oreb_home', 'dreb_home',
#        'reb_home', 'ast_home', 'stl_home', 'blk_home', 'tov_home', 'pf_home',
#        'pts_home', 'plus_minus_home', 'video_available_home', 'team_id_away',
#        'team_abbreviation_away', 'team_name_away', 'matchup_away', 'wl_away',
#        'fgm_away', 'fga_away', 'fg_pct_away', 'fg3m_away', 'fg3a_away',
#        'fg3_pct_away', 'ftm_away', 'fta_away', 'ft_pct_away', 'oreb_away',
#        'dreb_away', 'reb_away', 'ast_away', 'stl_away', 'blk_away', 'tov_away',
#        'pf_away', 'pts_away', 'plus_minus_away', 'video_available_away',
#        'season_type', 'year'],
#       dtype='object')

# %%
new_game = df_game.loc[:,['season_id', 'game_id', 'team_name_home', 'wl_home', 'team_name_away', 'wl_away']]
new_game
# Out:
#        season_id   game_id          team_name_home wl_home  \
# 48459      22009  20900476      Los Angeles Lakers       W
# 48460      22009  20900474           Atlanta Hawks       L
# 48461      22009  20900475  Minnesota Timberwolves       L
# 48462      22009  20900480      Washington Wizards       L
# 48463      22009  20900485            Phoenix Suns       L
# ...          ...       ...                     ...     ...
# 65537      22022  22201220         New York Knicks       L
# 65538      22022  22201217           Brooklyn Nets       L
# 65539      22022  22201223           Chicago Bulls       W
# 65540      22022  22201221         Toronto Raptors       W
# 65541      22022  22201218     Cleveland Cavaliers       L
#
#            team_name_away wl_away
# 48459    Sacramento Kings       L
# 48460     New York Knicks       W
# 48461       Orlando Magic       W
# 48462   San Antonio Spurs       W
# 48463   Memphis Grizzlies       W
# ...                   ...     ...
# ...

# %%
game_by_team_home = new_game.groupby(['team_name_home', 'season_id'])['wl_home'].value_counts(ascending=True).reset_index(name='total')
game_by_team_home
# Out:
#          team_name_home  season_id wl_home  total
# 0         Atlanta Hawks      22009       L      4
# 1         Atlanta Hawks      22009       W     22
# 2         Atlanta Hawks      22010       L     17
# 3         Atlanta Hawks      22010       W     24
# 4         Atlanta Hawks      22011       L     10
# ..                  ...        ...     ...    ...
# 775  Washington Wizards      22020       W     19
# 776  Washington Wizards      22021       L     20
# 777  Washington Wizards      22021       W     21
# 778  Washington Wizards      22022       W     19
# 779  Washington Wizards      22022       L     22
#
# [780 rows x 4 columns]

# %%
game_by_team_away = new_game.groupby(['team_name_away', 'season_id'])['wl_away'].value_counts(ascending=True).reset_index(name='total')
game_by_team_away.sort_values(by=['team_name_away', 'season_id','wl_away'])
# Out:
#          team_name_away  season_id wl_away  total
# 1         Atlanta Hawks      22009       L     15
# 0         Atlanta Hawks      22009       W     10
# 3         Atlanta Hawks      22010       L     21
# 2         Atlanta Hawks      22010       W     20
# 4         Atlanta Hawks      22011       L     16
# ..                  ...        ...     ...    ...
# 774  Washington Wizards      22020       W     15
# 777  Washington Wizards      22021       L     27
# 776  Washington Wizards      22021       W     14
# 779  Washington Wizards      22022       L     25
# 778  Washington Wizards      22022       W     16
#
# [780 rows x 4 columns]

# %%
research = new_game.groupby(['team_name_away', 'season_id'])['wl_away'].value_counts(ascending=True).reset_index(name='total_away')
amb1_1 = new_game.groupby(['team_name_home', 'season_id'])['wl_home'].value_counts(ascending=False).reset_index(name='total_home')
research.insert(loc=len(research.columns), column='total_home', value=amb1_1['total_home'])
colomns_list = ['total_home', 'total_away']
research['somme'] = research[colomns_list].sum(axis=1)
research
# Out:
#          team_name_away  season_id wl_away  total_away  total_home  somme
# 0         Atlanta Hawks      22009       W          10          22     32
# 1         Atlanta Hawks      22009       L          15           4     19
# 2         Atlanta Hawks      22010       W          20          24     44
# 3         Atlanta Hawks      22010       L          21          17     38
# 4         Atlanta Hawks      22011       L          16          23     39
# ..                  ...        ...     ...         ...         ...    ...
# 775  Washington Wizards      22020       L          21          17     38
# 776  Washington Wizards      22021       W          14          21     35
# 777  Washington Wizards      22021       L          27          20     47
# 778  Washington Wizards      22022       W          16          22     38
# 779  Washington Wizards      22022       L          25          19     44
#
# [780 rows x 6 columns]

# %%
research = new_game.groupby(['team_name_away', 'season_id'])['wl_away'].value_counts().reset_index(name='total_away')
amb1_1 = new_game.groupby(['team_name_home', 'season_id'])['wl_home'].value_counts().reset_index(name='total_home')
research.insert(loc=len(research.columns), column='total_home', value=amb1_1['total_home'])
research = research.sort_values(by=['team_name_away', 'season_id', 'wl_away'])
colomns_list = ['total_home', 'total_away']
research['somme'] = research[colomns_list].sum(axis=1)
research
# Out:
#          team_name_away  season_id wl_away  total_away  total_home  somme
# 0         Atlanta Hawks      22009       L          15          22     37
# 1         Atlanta Hawks      22009       W          10           4     14
# 2         Atlanta Hawks      22010       L          21          24     45
# 3         Atlanta Hawks      22010       W          20          17     37
# 5         Atlanta Hawks      22011       L          16          10     26
# ..                  ...        ...     ...         ...         ...    ...
# 775  Washington Wizards      22020       W          15          17     32
# 776  Washington Wizards      22021       L          27          21     48
# 777  Washington Wizards      22021       W          14          20     34
# 778  Washington Wizards      22022       L          25          22     47
# 779  Washington Wizards      22022       W          16          19     35
#
# [780 rows x 6 columns]

# %%
new = research.loc[research['wl_away'] == 'W']
new
# Out:
#          team_name_away  season_id wl_away  total_away  total_home  somme
# 1         Atlanta Hawks      22009       W          10           4     14
# 3         Atlanta Hawks      22010       W          20          17     37
# 4         Atlanta Hawks      22011       W          17          23     40
# 7         Atlanta Hawks      22013       W          14          17     31
# 8         Atlanta Hawks      22014       W          25          35     60
# ..                  ...        ...     ...         ...         ...    ...
# 771  Washington Wizards      22018       W          10          19     29
# 773  Washington Wizards      22019       W           9          16     25
# 775  Washington Wizards      22020       W          15          17     32
# 777  Washington Wizards      22021       W          14          20     34
# 779  Washington Wizards      22022       W          16          19     35
#
# [390 rows x 6 columns]

# %%
def supprimer_premier_2(valeur):
    valeur_str = str(valeur)
    return int(valeur_str.replace('2', '', 1)) if '2' in valeur_str else valeur

# %%
new_game2 = new.loc[:,['team_name_away', 'season_id', 'somme']]
new_game2['season_id'] = new_game2['season_id'].apply(supprimer_premier_2)
new_game2
# Out:
#          team_name_away  season_id  somme
# 1         Atlanta Hawks       2009     14
# 3         Atlanta Hawks       2010     37
# 4         Atlanta Hawks       2011     40
# 7         Atlanta Hawks       2013     31
# 8         Atlanta Hawks       2014     60
# ..                  ...        ...    ...
# 771  Washington Wizards       2018     29
# 773  Washington Wizards       2019     25
# 775  Washington Wizards       2020     32
# 777  Washington Wizards       2021     34
# 779  Washington Wizards       2022     35
#
# [390 rows x 3 columns]

# %%
new_game2['season'] = pd.to_datetime(new_game2['season_id'], format='%Y').dt.year
new_game2
# Out:
#          team_name_away  season_id  somme  season
# 1         Atlanta Hawks       2009     14    2009
# 3         Atlanta Hawks       2010     37    2010
# 4         Atlanta Hawks       2011     40    2011
# 7         Atlanta Hawks       2013     31    2013
# 8         Atlanta Hawks       2014     60    2014
# ..                  ...        ...    ...     ...
# 771  Washington Wizards       2018     29    2018
# 773  Washington Wizards       2019     25    2019
# 775  Washington Wizards       2020     32    2020
# 777  Washington Wizards       2021     34    2021
# 779  Washington Wizards       2022     35    2022
#
# [390 rows x 4 columns]

# %%
new_game2 = new_game2.loc[:,['team_name_away', 'season', 'somme']]
new_game2
# Out:
#          team_name_away  season  somme
# 1         Atlanta Hawks    2009     14
# 3         Atlanta Hawks    2010     37
# 4         Atlanta Hawks    2011     40
# 7         Atlanta Hawks    2013     31
# 8         Atlanta Hawks    2014     60
# ..                  ...     ...    ...
# 771  Washington Wizards    2018     29
# 773  Washington Wizards    2019     25
# 775  Washington Wizards    2020     32
# 777  Washington Wizards    2021     34
# 779  Washington Wizards    2022     35
#
# [390 rows x 3 columns]

# %%
import matplotlib.pyplot as plt

# %%
# Tracer un graphique en ligne pour chaque nom
plt.figure(figsize=(10, 6))

# Utiliser groupby pour tracer des lignes pour chaque nom
for nom, group in new_game2.groupby('team_name_away'):
    plt.plot(group['season'], group['somme'], marker='o', linestyle='-', label=nom)

# Ajouter des titres et des labels
plt.title('Nombre de matchs gagnés annuellement par les équipes')
plt.xlabel('Année')
plt.ylabel('Matchs gagnés')
plt.legend(title='Equipes')
plt.grid(True)

# Afficher le graphique
plt.show()

# %%
df_other_stats = pd.read_csv('other_stats.csv')
df_other_stats.head()
# Out:
#     game_id  league_id  team_id_home team_abbreviation_home team_city_home  \
# 0  29600012          0    1610612756                    PHX        Phoenix
# 1  29600005          0    1610612737                    ATL        Atlanta
# 2  29600002          0    1610612739                    CLE      Cleveland
# 3  29600007          0    1610612754                    IND        Indiana
# 4  29600013          0    1610612746                    LAC    Los Angeles
#
#    pts_paint_home  pts_2nd_chance_home  pts_fb_home  largest_lead_home  \
# 0              44                   18            2                  1
# 1              32                    9            6                  0
# 2              36                   14            6                 20
# 3              34                   11            4                 10
# 4              40                   19            2                 12
#
#    lead_changes  ...  team_abbreviation_away  team_city_away  pts_paint_away  \
# ...

# %%
df_other_stats.columns
# Out:
# Index(['game_id', 'league_id', 'team_id_home', 'team_abbreviation_home',
#        'team_city_home', 'pts_paint_home', 'pts_2nd_chance_home',
#        'pts_fb_home', 'largest_lead_home', 'lead_changes', 'times_tied',
#        'team_turnovers_home', 'total_turnovers_home', 'team_rebounds_home',
#        'pts_off_to_home', 'team_id_away', 'team_abbreviation_away',
#        'team_city_away', 'pts_paint_away', 'pts_2nd_chance_away',
#        'pts_fb_away', 'largest_lead_away', 'team_turnovers_away',
#        'total_turnovers_away', 'team_rebounds_away', 'pts_off_to_away'],
#       dtype='object')

# %%
# df.to_csv('dataframe.csv')

# %%
# px.pie(new_df, 
#         names="team_name_home", values="draft_year", 
#         title='NBA organization type from 2010 to 2023', hole=0.3)

# %%
df_common_player_info = pd.read_csv('common_player_info.csv')
df_common_player_info.head()
# Out:
#    person_id first_name     last_name   display_first_last  \
# 0      76001       Alaa     Abdelnaby       Alaa Abdelnaby
# 1      76002       Zaid    Abdul-Aziz      Zaid Abdul-Aziz
# 2      76003     Kareem  Abdul-Jabbar  Kareem Abdul-Jabbar
# 3        949    Shareef   Abdur-Rahim  Shareef Abdur-Rahim
# 4      76006     Forest          Able          Forest Able
#
#   display_last_comma_first  display_fi_last          player_slug  \
# 0          Abdelnaby, Alaa     A. Abdelnaby       alaa-abdelnaby
# 1         Abdul-Aziz, Zaid    Z. Abdul-Aziz      zaid-abdul-aziz
# 2     Abdul-Jabbar, Kareem  K. Abdul-Jabbar  kareem-abdul-jabbar
# 3     Abdur-Rahim, Shareef   S. Abdur-Rahim  shareef-abdur-rahim
# 4             Able, Forest          F. Able          forest-able
#
#              birthdate            school country  ...  \
# 0  1968-06-24 00:00:00              Duke     USA  ...
# 1  1946-04-07 00:00:00        Iowa State     USA  ...
# ...

# %%
df_common_player_info.describe(include='all')
# Out:
#            person_id first_name last_name display_first_last  \
# count   3.632000e+03       3632      3632               3632
# unique           NaN       1291      2308               3608
# top              NaN       John  Williams      Charles Smith
# freq             NaN         79        70                  3
# mean    3.359710e+05        NaN       NaN                NaN
# std     5.796896e+05        NaN       NaN                NaN
# min     2.000000e+00        NaN       NaN                NaN
# 25%     7.613600e+04        NaN       NaN                NaN
# 50%     7.782650e+04        NaN       NaN                NaN
# 75%     2.023328e+05        NaN       NaN                NaN
# max     1.641645e+06        NaN       NaN                NaN
#
#        display_last_comma_first display_fi_last    player_slug  \
# count                      3632            3632           3632
# unique                     3608            3232           3608
# ...

# %%
player_position = df_common_player_info.loc[:,['display_first_last', 'position']]
player_position.describe(include='all')
# Out:
#        display_first_last position
# count                3632     3587
# unique               3608        7
# top         Charles Smith    Guard
# freq                    3     1416

# %%
player_position = player_position.fillna('other')
player_position.describe(include='all')
# Out:
#        display_first_last position
# count                3632     3632
# unique               3608        8
# top         Charles Smith    Guard
# freq                    3     1416
