# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_NBA.csv')
df
# Out:
#       Unnamed: 0                Team  season  win_match  overall_pick  \
# 0              0       Atlanta Hawks    2000       25.0          28.0
# 1              1       Atlanta Hawks    2001       33.0          22.0
# 2              2       Atlanta Hawks    2002       35.0          20.0
# 3              3       Atlanta Hawks    2003       28.0          10.0
# 4              4       Atlanta Hawks    2003       28.0          20.0
# ...          ...                 ...     ...        ...           ...
# 1314        1314  Washington Wizards    2023        NaN           9.0
# 1315        1315  Washington Wizards    2024        NaN          37.0
# 1316        1316  Washington Wizards    2025        NaN          15.0
# 1317        1317  Washington Wizards    2026        NaN          10.0
# 1318        1318  Washington Wizards    2026        NaN          10.0
#
#            position
# 0            Center
# 1             Guard
# 2           Forward
# 3             Guard
# 4     Forward-Guard
# ...             ...
# 1314        Forward
# 1315          Guard
# 1316        Forward
# 1317          Guard
# 1318          Guard
#
# [1319 rows x 6 columns]

# %%
# list = 'Phoenix Suns'
list = input("Ville suivi du nom de l'équipe : ")
df = df[df['Team'].isin([list])]
df
# Out:
#      Unnamed: 0            Team  season  win_match  overall_pick  \
# 49           49  Boston Celtics    2000       36.0           6.0
# 50           50  Boston Celtics    2000       36.0          38.0
# 51           51  Boston Celtics    2001       49.0           3.0
# 52           52  Boston Celtics    2001       49.0           6.0
# 53           53  Boston Celtics    2002       44.0          10.0
# 54           54  Boston Celtics    2003       36.0          61.0
# 55           55  Boston Celtics    2004       45.0          11.0
# 56           56  Boston Celtics    2005       33.0          10.0
# 57           57  Boston Celtics    2005       33.0          21.0
# 58           58  Boston Celtics    2006       24.0          49.0
# 59           59  Boston Celtics    2007       66.0          16.0
# 60           60  Boston Celtics    2007       66.0          20.0
# 61           61  Boston Celtics    2008       62.0          15.0
# 62           62  Boston Celtics    2008       62.0          24.0
# 63           63  Boston Celtics    2008       62.0          25.0
# 64           64  Boston Celtics    2008       62.0          40.0
# 65           65  Boston Celtics    2009       50.0          18.0
# 66           66  Boston Celtics    2009       50.0          50.0
# 67           67  Boston Celtics    2009       50.0          53.0
# 68           68  Boston Celtics    2010       56.0           7.0
# 69           69  Boston Celtics    2011       39.0           5.0
# 70           70  Boston Celtics    2011       39.0          32.0
# 71           71  Boston Celtics    2012        NaN          30.0
# 72           72  Boston Celtics    2012        NaN          60.0
# 73           73  Boston Celtics    2013       25.0          58.0
# 74           74  Boston Celtics    2014       40.0          19.0
# 75           75  Boston Celtics    2014       40.0          52.0
# 76           76  Boston Celtics    2015       48.0          25.0
# 77           77  Boston Celtics    2015       48.0          55.0
# 78           78  Boston Celtics    2016       53.0          21.0
# 79           79  Boston Celtics    2016       53.0          22.0
# 80           80  Boston Celtics    2016       53.0          51.0
# 81           81  Boston Celtics    2017       55.0          61.0
# 82           82  Boston Celtics    2018       49.0          61.0
# 83           83  Boston Celtics    2019       48.0          16.0
# 84           84  Boston Celtics    2019       48.0          28.0
# 85           85  Boston Celtics    2019       48.0          33.0
# 86           86  Boston Celtics    2019       48.0          45.0
# 87           87  Boston Celtics    2020       36.0           3.0
# 88           88  Boston Celtics    2020       36.0          16.0
# 89           89  Boston Celtics    2020       36.0          23.0
# 90           90  Boston Celtics    2020       36.0          45.0
# 91           91  Boston Celtics    2020       36.0          51.0
# 92           92  Boston Celtics    2020       36.0          58.0
# 93           93  Boston Celtics    2021       51.0           3.0
# 94           94  Boston Celtics    2021       51.0          37.0
# 95           95  Boston Celtics    2021       51.0          53.0
# 96           96  Boston Celtics    2021       51.0          56.0
# 97           97  Boston Celtics    2022       57.0          27.0
# 98           98  Boston Celtics    2023        NaN          14.0
# 99           99  Boston Celtics    2023        NaN          20.0
# 100         100  Boston Celtics    2023        NaN          22.0
# 101         101  Boston Celtics    2023        NaN          51.0
# 102         102  Boston Celtics    2024        NaN          14.0
# 103         103  Boston Celtics    2024        NaN          26.0
# 104         104  Boston Celtics    2024        NaN          30.0
# 105         105  Boston Celtics    2026        NaN          53.0
#
#            position
# 49          Forward
# 50           Center
# 51            Guard
# 52    Guard-Forward
# 53          Forward
# 54          Nothing
# 55          Forward
# 56    Guard-Forward
# 57            Guard
# 58          Forward
# 59            Guard
# 60    Guard-Forward
# 61           Center
# 62            Guard
# 63    Guard-Forward
# 64          Forward
# 65    Guard-Forward
# 66          Forward
# 67            Guard
# 68            Guard
# 69          Forward
# 70            Guard
# 71            Guard
# 72           Center
# 73            Guard
# 74            Guard
# 75          Forward
# 76            Guard
# 77            Guard
# 78   Center-Forward
# 79           Center
# 80          Forward
# 81          Nothing
# 82          Nothing
# 83            Guard
# 84            Guard
# 85   Center-Forward
# 86    Guard-Forward
# 87    Guard-Forward
# 88          Forward
# 89           Center
# 90            Guard
# 91          Forward
# 92          Forward
# 93    Forward-Guard
# 94          Forward
# 95            Guard
# 96            Guard
# 97   Center-Forward
# 98    Guard-Forward
# 99    Guard-Forward
# 100         Forward
# 101           Guard
# 102   Guard-Forward
# 103           Guard
# 104           Guard
# 105           Guard

# %%
# df = (df.groupby(['season', 'Team', 'win_match', 'position'], dropna=False)['overall_pick'].sum()/df.groupby(['season', 'Team', 'win_match', 'position'], dropna=False)['overall_pick'].count()).reset_index(name='total_pick')
df = df.groupby(['season', 'Team', 'win_match', 'position'], dropna=False)['overall_pick'].min().reset_index(name='total_pick')

# %%
Max = df['total_pick'].max()
Min = 1
df['total_pick'] = df.apply(lambda x: Max + Min - x['total_pick'], axis=1)

# %%
df
# Out:
#     season            Team  win_match        position  total_pick
# 0     2000  Boston Celtics       36.0          Center        24.0
# 1     2000  Boston Celtics       36.0         Forward        56.0
# 2     2001  Boston Celtics       49.0           Guard        59.0
# 3     2001  Boston Celtics       49.0   Guard-Forward        56.0
# 4     2002  Boston Celtics       44.0         Forward        52.0
# 5     2003  Boston Celtics       36.0         Nothing         1.0
# 6     2004  Boston Celtics       45.0         Forward        51.0
# 7     2005  Boston Celtics       33.0           Guard        41.0
# 8     2005  Boston Celtics       33.0   Guard-Forward        52.0
# 9     2006  Boston Celtics       24.0         Forward        13.0
# 10    2007  Boston Celtics       66.0           Guard        46.0
# 11    2007  Boston Celtics       66.0   Guard-Forward        42.0
# 12    2008  Boston Celtics       62.0          Center        47.0
# 13    2008  Boston Celtics       62.0         Forward        22.0
# 14    2008  Boston Celtics       62.0           Guard        38.0
# 15    2008  Boston Celtics       62.0   Guard-Forward        37.0
# 16    2009  Boston Celtics       50.0         Forward        12.0
# 17    2009  Boston Celtics       50.0           Guard         9.0
# 18    2009  Boston Celtics       50.0   Guard-Forward        44.0
# 19    2010  Boston Celtics       56.0           Guard        55.0
# 20    2011  Boston Celtics       39.0         Forward        57.0
# 21    2011  Boston Celtics       39.0           Guard        30.0
# 22    2012  Boston Celtics        NaN          Center         2.0
# 23    2012  Boston Celtics        NaN           Guard        32.0
# 24    2013  Boston Celtics       25.0           Guard         4.0
# 25    2014  Boston Celtics       40.0         Forward        10.0
# 26    2014  Boston Celtics       40.0           Guard        43.0
# 27    2015  Boston Celtics       48.0           Guard        37.0
# 28    2016  Boston Celtics       53.0          Center        40.0
# 29    2016  Boston Celtics       53.0  Center-Forward        41.0
# 30    2016  Boston Celtics       53.0         Forward        11.0
# 31    2017  Boston Celtics       55.0         Nothing         1.0
# 32    2018  Boston Celtics       49.0         Nothing         1.0
# 33    2019  Boston Celtics       48.0  Center-Forward        29.0
# 34    2019  Boston Celtics       48.0           Guard        46.0
# 35    2019  Boston Celtics       48.0   Guard-Forward        17.0
# 36    2020  Boston Celtics       36.0          Center        39.0
# 37    2020  Boston Celtics       36.0         Forward        46.0
# 38    2020  Boston Celtics       36.0           Guard        17.0
# 39    2020  Boston Celtics       36.0   Guard-Forward        59.0
# 40    2021  Boston Celtics       51.0         Forward        25.0
# 41    2021  Boston Celtics       51.0   Forward-Guard        59.0
# 42    2021  Boston Celtics       51.0           Guard         9.0
# 43    2022  Boston Celtics       57.0  Center-Forward        35.0
# 44    2023  Boston Celtics        NaN         Forward        40.0
# 45    2023  Boston Celtics        NaN           Guard        11.0
# 46    2023  Boston Celtics        NaN   Guard-Forward        48.0
# 47    2024  Boston Celtics        NaN           Guard        36.0
# 48    2024  Boston Celtics        NaN   Guard-Forward        48.0
# 49    2026  Boston Celtics        NaN           Guard         9.0

# %%
df.fillna("NaN",inplace=True)
df
# Out:
# C:\Users\NewNoe\AppData\Local\Temp\ipykernel_24616\2877348447.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'NaN' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna("NaN",inplace=True)
#     season            Team win_match        position  total_pick
# 0     2000  Boston Celtics      36.0          Center        24.0
# 1     2000  Boston Celtics      36.0         Forward        56.0
# 2     2001  Boston Celtics      49.0           Guard        59.0
# 3     2001  Boston Celtics      49.0   Guard-Forward        56.0
# 4     2002  Boston Celtics      44.0         Forward        52.0
# 5     2003  Boston Celtics      36.0         Nothing         1.0
# 6     2004  Boston Celtics      45.0         Forward        51.0
# 7     2005  Boston Celtics      33.0           Guard        41.0
# 8     2005  Boston Celtics      33.0   Guard-Forward        52.0
# 9     2006  Boston Celtics      24.0         Forward        13.0
# 10    2007  Boston Celtics      66.0           Guard        46.0
# 11    2007  Boston Celtics      66.0   Guard-Forward        42.0
# 12    2008  Boston Celtics      62.0          Center        47.0
# 13    2008  Boston Celtics      62.0         Forward        22.0
# 14    2008  Boston Celtics      62.0           Guard        38.0
# 15    2008  Boston Celtics      62.0   Guard-Forward        37.0
# 16    2009  Boston Celtics      50.0         Forward        12.0
# 17    2009  Boston Celtics      50.0           Guard         9.0
# 18    2009  Boston Celtics      50.0   Guard-Forward        44.0
# 19    2010  Boston Celtics      56.0           Guard        55.0
# 20    2011  Boston Celtics      39.0         Forward        57.0
# 21    2011  Boston Celtics      39.0           Guard        30.0
# 22    2012  Boston Celtics       NaN          Center         2.0
# 23    2012  Boston Celtics       NaN           Guard        32.0
# 24    2013  Boston Celtics      25.0           Guard         4.0
# 25    2014  Boston Celtics      40.0         Forward        10.0
# 26    2014  Boston Celtics      40.0           Guard        43.0
# 27    2015  Boston Celtics      48.0           Guard        37.0
# 28    2016  Boston Celtics      53.0          Center        40.0
# 29    2016  Boston Celtics      53.0  Center-Forward        41.0
# 30    2016  Boston Celtics      53.0         Forward        11.0
# 31    2017  Boston Celtics      55.0         Nothing         1.0
# 32    2018  Boston Celtics      49.0         Nothing         1.0
# 33    2019  Boston Celtics      48.0  Center-Forward        29.0
# 34    2019  Boston Celtics      48.0           Guard        46.0
# 35    2019  Boston Celtics      48.0   Guard-Forward        17.0
# 36    2020  Boston Celtics      36.0          Center        39.0
# 37    2020  Boston Celtics      36.0         Forward        46.0
# 38    2020  Boston Celtics      36.0           Guard        17.0
# 39    2020  Boston Celtics      36.0   Guard-Forward        59.0
# 40    2021  Boston Celtics      51.0         Forward        25.0
# 41    2021  Boston Celtics      51.0   Forward-Guard        59.0
# 42    2021  Boston Celtics      51.0           Guard         9.0
# 43    2022  Boston Celtics      57.0  Center-Forward        35.0
# 44    2023  Boston Celtics       NaN         Forward        40.0
# 45    2023  Boston Celtics       NaN           Guard        11.0
# 46    2023  Boston Celtics       NaN   Guard-Forward        48.0
# 47    2024  Boston Celtics       NaN           Guard        36.0
# 48    2024  Boston Celtics       NaN   Guard-Forward        48.0
# 49    2026  Boston Celtics       NaN           Guard         9.0

# %%
def category(valeur):
    if valeur == 'NaN':
        pass
    elif valeur <= 10:
        return 'A'
    elif valeur <= 20:
        return "B"
    elif valeur <= 30:
        return "C"
    elif valeur <= 35:
        return "D"
    elif valeur <= 40:
        return "E"
    elif valeur <= 45:
        return "F"
    elif valeur <= 50:
        return "G"
    elif valeur <= 55:
        return "H"
    elif valeur <= 60:
        return "I"
    elif valeur <= 65:
        return "J"
    elif valeur <= 70:
        return "K"
    elif valeur <= 80:
        return "L"
    else:
        return "M"

# %%
df['win_match'] = df['win_match'].apply(category)
df
# Out:
#     season            Team win_match        position  total_pick
# 0     2000  Boston Celtics         E          Center        24.0
# 1     2000  Boston Celtics         E         Forward        56.0
# 2     2001  Boston Celtics         G           Guard        59.0
# 3     2001  Boston Celtics         G   Guard-Forward        56.0
# 4     2002  Boston Celtics         F         Forward        52.0
# 5     2003  Boston Celtics         E         Nothing         1.0
# 6     2004  Boston Celtics         F         Forward        51.0
# 7     2005  Boston Celtics         D           Guard        41.0
# 8     2005  Boston Celtics         D   Guard-Forward        52.0
# 9     2006  Boston Celtics         C         Forward        13.0
# 10    2007  Boston Celtics         K           Guard        46.0
# 11    2007  Boston Celtics         K   Guard-Forward        42.0
# 12    2008  Boston Celtics         J          Center        47.0
# 13    2008  Boston Celtics         J         Forward        22.0
# 14    2008  Boston Celtics         J           Guard        38.0
# 15    2008  Boston Celtics         J   Guard-Forward        37.0
# 16    2009  Boston Celtics         G         Forward        12.0
# 17    2009  Boston Celtics         G           Guard         9.0
# 18    2009  Boston Celtics         G   Guard-Forward        44.0
# 19    2010  Boston Celtics         I           Guard        55.0
# 20    2011  Boston Celtics         E         Forward        57.0
# 21    2011  Boston Celtics         E           Guard        30.0
# 22    2012  Boston Celtics      None          Center         2.0
# 23    2012  Boston Celtics      None           Guard        32.0
# 24    2013  Boston Celtics         C           Guard         4.0
# 25    2014  Boston Celtics         E         Forward        10.0
# 26    2014  Boston Celtics         E           Guard        43.0
# 27    2015  Boston Celtics         G           Guard        37.0
# 28    2016  Boston Celtics         H          Center        40.0
# 29    2016  Boston Celtics         H  Center-Forward        41.0
# 30    2016  Boston Celtics         H         Forward        11.0
# 31    2017  Boston Celtics         H         Nothing         1.0
# 32    2018  Boston Celtics         G         Nothing         1.0
# 33    2019  Boston Celtics         G  Center-Forward        29.0
# 34    2019  Boston Celtics         G           Guard        46.0
# 35    2019  Boston Celtics         G   Guard-Forward        17.0
# 36    2020  Boston Celtics         E          Center        39.0
# 37    2020  Boston Celtics         E         Forward        46.0
# 38    2020  Boston Celtics         E           Guard        17.0
# 39    2020  Boston Celtics         E   Guard-Forward        59.0
# 40    2021  Boston Celtics         H         Forward        25.0
# 41    2021  Boston Celtics         H   Forward-Guard        59.0
# 42    2021  Boston Celtics         H           Guard         9.0
# 43    2022  Boston Celtics         I  Center-Forward        35.0
# 44    2023  Boston Celtics      None         Forward        40.0
# 45    2023  Boston Celtics      None           Guard        11.0
# 46    2023  Boston Celtics      None   Guard-Forward        48.0
# 47    2024  Boston Celtics      None           Guard        36.0
# 48    2024  Boston Celtics      None   Guard-Forward        48.0
# 49    2026  Boston Celtics      None           Guard         9.0

# %%
df.to_csv('dataset_' + list + '_cat.csv')
